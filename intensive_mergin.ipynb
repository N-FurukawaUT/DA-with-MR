# %% [markdown]
# インテンシブマージン

# %%
import pandas as pd
import numpy as np
from import_data import facultyData
minorityReserveB, minorityReserveDA, M, shiteiDict, fac, bunri, categoryToList=facultyData.main()

# %%
trial=1000
MR_utility_dict=dict()
for f in fac:
    MR_utility_dict[f]=[]
for n in range(trial):
    majority_acceptance_MR=pd.read_csv(f"MultiThread/majority_acceptance_MR{n}.csv", index_col=0, header=None)
    minority_acceptance_MR=pd.read_csv(f"MultiThread/minority_acceptance_MR{n}.csv", index_col=0, header=None)
    utilityDict=pd.read_csv(f"MultiThread/utilityDict{n}.csv",header=0, index_col=0).to_dict(orient="index")
    for f in fac:
        cnt=0
        accept_students=majority_acceptance_MR.loc[f, :].dropna()
        utility=0
        for student in accept_students:
            utility+=utilityDict[student]["utility"]
            
        cnt+=len(accept_students)
            
        accept_students=minority_acceptance_MR.loc[f, :].dropna()
        for student in accept_students:
            utility+=utilityDict[student]["utility"]
        cnt+=len(accept_students)
        
        if cnt!=0:
            MR_utility_dict[f].append(utility/cnt)
        else:
            MR_utility_dict[f].append(0)
# for f in fac:
#     MR_utility_dict[f]={"効用の平均値":MR_utility_dict[f]/trial}
MR_utility_df=pd.DataFrame(MR_utility_dict)
MR_utility_df["平均値"]=MR_utility_df.mean()
MR_utility_df.to_csv("Result/新制度での生徒の進学平均点.csv", encoding="utf-8-sig")
print(MR_utility_df)
# Out:
#            法学部       経済学部   A群（思想文化）  B群（歴史文化_日本史学）  C群（歴史文化_東洋史学）  \
# 0    73.648311  72.520725  74.652907      75.055347      72.498106
# 1    74.446661  72.593263  75.260032      75.079381      71.947192
# 2    74.038908  73.030021  75.235344      76.110790      74.747338
# 3    74.264653  72.978473  75.069298      77.540645      71.303708
# 4    74.007955  73.240633  77.562204      73.507050      75.659653
# ..         ...        ...        ...            ...            ...
# 995  74.368740  73.180586  76.137872      75.380183      74.754167
# 996  73.748147  73.439778  73.953036      77.258502      73.196509
# 997  73.692845  72.867300  75.840412      76.623675      73.007854
# 998  74.363336  72.800498  73.969792      75.827133      75.868481
# 999  74.633979  72.600143  74.778146      76.769607      77.248896
#
#      D群（歴史文化_西洋史学）  E群（歴史文化_考古学）  F群（歴史文化_美術史学）   G群（言語文化）    H群（心理学）  ...  \
# 0        80.720865     74.592049      68.488329  73.926706  79.785711  ...
# 1        78.754302     71.622591      74.864850  72.705596  79.496508  ...
# 2        75.780040     73.712761      72.324618  73.370331  80.657889  ...
# 3        80.352080     70.436412      73.067595  73.912658  80.533032  ...
# 4        81.465497     71.043270      73.147863  72.403880  83.312682  ...
# ..             ...           ...            ...        ...        ...  ...
# 995      81.610784     69.564282      73.622067  72.482578  84.302619  ...
# 996      78.364097     71.584685      71.623041  73.719315  81.079902  ...
# 997      81.238793      0.000000      75.244759  75.248477  79.722413  ...
# 998      79.870590     77.061773      73.000452  73.522417  81.006207  ...
# 999      80.248765     70.787520      70.709658  74.108453  80.299367  ...
#
#           情報科学        物理学        天文学    地球惑星物理学    地球惑星環境学         化学  \
# 0    77.682560  75.922237  76.035420  76.525007  73.896122  76.217568
# 1    78.392550  72.669097  75.900252  76.233767  77.061067  78.199918
# 2    78.986959  73.481299  76.329668  77.218139  79.496366  78.194839
# 3    80.154374  74.252008  81.058483  77.570150  83.349009  77.803030
# 4    77.511597  76.494393  75.507498  77.497596  79.976455  77.630952
# ..         ...        ...        ...        ...        ...        ...
# 995  79.715209  75.627971  76.427855  76.937489  77.434040  76.652077
# 996  79.982392  73.595677  79.223324  75.920014  78.401895  75.917698
# 997  77.790372  75.748045  81.284590  76.368039  73.393907  76.219058
# 998  77.235731  73.976238  79.421415  78.813780  77.729491  76.919722
# 999  77.291888  73.464056  79.261224  75.481867  81.166915  75.969878
#
#           生物化学     生物情報科学        生物学  平均値
# 0    76.379149  79.375723  73.200038  NaN
# 1    78.052815  78.117154  74.614151  NaN
# 2    78.612858  79.843058  77.121113  NaN
# 3    78.864225  79.485673  75.055075  NaN
# 4    77.187791  76.149504  73.326684  NaN
# ..         ...        ...        ...  ...
# 995  77.323201  83.478350  77.744289  NaN
# 996  77.591192  79.647570  76.836794  NaN
# 997  74.403098  77.216785  74.654481  NaN
# 998  76.241230  75.963204  75.310889  NaN
# 999  77.884146  78.720380  77.508276  NaN
#
# [1000 rows x 79 columns]

# %%
trial=1000
MR_utility_dict=dict()
MR_utility_dict_m=dict()
for f in fac:
    MR_utility_dict[f]=[]
    MR_utility_dict_m[f]=[]
for n in range(trial):
    majority_acceptance_MR=pd.read_csv(f"MultiThread/majority_acceptance_MR{n}.csv", index_col=0, header=None)
    minority_acceptance_MR=pd.read_csv(f"MultiThread/minority_acceptance_MR{n}.csv", index_col=0, header=None)
    utilityDict=pd.read_csv(f"MultiThread/utilityDict{n}.csv",header=0, index_col=0).to_dict(orient="index")
    for f in fac:
        cnt=0
        accept_students=majority_acceptance_MR.loc[f, :].dropna()
        utility=0
        for student in accept_students:
            utility+=utilityDict[student]["utility"]
            
        cnt+=len(accept_students)
        
        cnt_m=0
        utility_m=0    
        accept_students=minority_acceptance_MR.loc[f, :].dropna()
        for student in accept_students:
            utility_m+=utilityDict[student]["utility"]
        cnt_m+=len(accept_students)
        
        if cnt!=0:
            MR_utility_dict[f].append(utility/cnt)
        else:
            MR_utility_dict[f].append(0)

        if cnt_m!=0:
            MR_utility_dict_m[f].append(utility_m/cnt_m)
        else:
            MR_utility_dict_m[f].append(0)
# for f in fac:
#     MR_utility_dict[f]={"効用の平均値":MR_utility_dict[f]/trial}
MR_utility_df=pd.DataFrame(MR_utility_dict)
MR_utility_df.to_csv("Result/新制度での生徒の進学平均点(全科類枠).csv", encoding="utf-8-sig")
print(MR_utility_df)
MR_utility_df_m=pd.DataFrame(MR_utility_dict_m)
MR_utility_df_m.to_csv("Result/新制度での生徒の進学平均点(指定科類枠).csv", encoding="utf-8-sig")
print(MR_utility_df_m)
# Out:
#            法学部       経済学部   A群（思想文化）  B群（歴史文化_日本史学）  C群（歴史文化_東洋史学）  \
# 0    71.710506  70.670439  75.566562      75.055347      72.657266
# 1    72.167076  70.198135  75.883155      75.973593      71.947192
# 997  74.659890  74.366810  71.644039      65.123769       0.000000
# 998  74.846399  74.019547  71.579966      71.519305       0.000000
# 999  75.470175  73.519496  72.143828      72.358928       0.000000
#
#      D群（歴史文化_西洋史学）  E群（歴史文化_考古学）  F群（歴史文化_美術史学）   G群（言語文化）    H群（心理学）  ...  \
# 0        69.806552     77.948942      70.084234  72.185657  81.358899  ...
# 1        75.569982     70.829825      74.764327  71.985860  81.468989  ...
# 2        71.354685     67.179298      72.324618  71.164768  84.214478  ...
# 3        68.950075     71.495946      72.460077  72.641511  80.487316  ...
# 4        77.428147     75.555126      73.256304  72.913415  84.806161  ...
# ..             ...           ...            ...        ...        ...  ...
# 995      74.778715     63.683390      73.622067  68.452322  82.460582  ...
# 996      74.117358     70.799519      71.829114  73.317973  82.714425  ...
# 997      75.734650      0.000000      75.244759  74.707309  82.848967  ...
# 998       0.000000     76.023111      73.000452  72.656952  83.558227  ...
# 999      72.569707     72.690086      70.709658  71.815394  83.059884  ...
#
#      数学  情報科学  物理学  天文学  地球惑星物理学    地球惑星環境学         化学       生物化学     生物情報科学  \
# 0     0     0    0    0        0  74.811369  76.217568  76.379149  79.375723
# 1     0     0    0    0        0  78.138220  78.199918  78.052815  78.117154
# 2     0     0    0    0        0  80.464663  78.194839  78.612858  79.843058
# 3     0     0    0    0        0  85.985780  77.803030  78.864225  79.485673
# 4     0     0    0    0        0  81.686447  77.630952  77.187791  76.149504
# ..   ..   ...  ...  ...      ...        ...        ...        ...        ...
# 995   0     0    0    0        0  78.890605  76.652077  77.323201  83.478350
# 996   0     0    0    0        0  79.593196  75.917698  77.591192  79.647570
# 997   0     0    0    0        0  74.359485  76.219058  74.403098  77.216785
# 998   0     0    0    0        0  78.459779  76.919722  76.241230  75.963204
# 999   0     0    0    0        0  82.722333  75.969878  77.884146  78.720380
#
#      生物学
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ..   ...
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
#
# [1000 rows x 78 columns]

# %%
trial=1000
MR_utility_dict=dict()
zero_count_MR=dict()
for f in fac:
    MR_utility_dict[f]=0
    zero_count_MR[f]=0
for n in range(trial):
    majority_acceptance_MR=pd.read_csv(f"MultiThread/majority_acceptance_MR{n}.csv", index_col=0, header=None)
    minority_acceptance_MR=pd.read_csv(f"MultiThread/minority_acceptance_MR{n}.csv", index_col=0, header=None)
    utilityDict=pd.read_csv(f"MultiThread/utilityDict{n}.csv",header=0, index_col=0).to_dict(orient="index")
    for f in fac:
        cnt=0
        accept_students=majority_acceptance_MR.loc[f, :].dropna()
        utility=0
        for student in accept_students:
            utility+=utilityDict[student]["utility"]
            
        cnt+=len(accept_students)
            
        accept_students=minority_acceptance_MR.loc[f, :].dropna()
        for student in accept_students:
            utility+=utilityDict[student]["utility"]
        cnt+=len(accept_students)
        
        if cnt!=0:
            MR_utility_dict[f]+=(utility/cnt)
        else:
            zero_count_MR[f]+=1
for f in fac:
    MR_utility_dict[f]={"効用の平均値":MR_utility_dict[f]/(trial-zero_count_MR[f])}
MR_utility_df=pd.DataFrame(MR_utility_dict).T
MR_utility_df.to_csv("Result/新制度での生徒の進学平均点(内定なし除く).csv", encoding="utf-8-sig")
print(MR_utility_df)
# Out:
#                   効用の平均値
# 法学部            74.009219
# 経済学部           72.967457
# A群（思想文化）       75.042657
# B群（歴史文化_日本史学）  75.830295
# C群（歴史文化_東洋史学）  74.092831
# ...                  ...
# 地球惑星環境学        79.120312
# 化学             76.056548
# 生物化学           77.717825
# 生物情報科学         78.837209
# 生物学            75.814144
#
# [78 rows x 1 columns]

# %% [markdown]
# 新制度での効用合計値

# %%
trial=1000
MR_utility_dict=dict()
for f in fac:
    MR_utility_dict[f]=[]
for n in range(trial):
    majority_acceptance_MR=pd.read_csv(f"MultiThread/majority_acceptance_MR{n}.csv", index_col=0, header=None)
    minority_acceptance_MR=pd.read_csv(f"MultiThread/minority_acceptance_MR{n}.csv", index_col=0, header=None)
    utilityDict=pd.read_csv(f"MultiThread/utilityDict{n}.csv",header=0, index_col=0).to_dict(orient="index")
    for f in fac:
        accept_students=majority_acceptance_MR.loc[f, :].dropna()
        utility=0
        for student in accept_students:
            utility+=utilityDict[student]["utility"]
            
        accept_students=minority_acceptance_MR.loc[f, :].dropna()
        for student in accept_students:
            utility+=utilityDict[student]["utility"]
        MR_utility_dict[f].append(utility)
# for f in fac:
#     MR_utility_dict[f]={"効用の合計値":MR_utility_dict[f]/trial}
MR_utility_df=pd.DataFrame(MR_utility_dict)
MR_utility_df.loc["平均値"]=MR_utility_df.mean()
MR_utility_df.to_csv("Result/新制度での学科の効用.csv", encoding="utf-8-sig")
print(MR_utility_df)
# Out:
#              法学部         経済学部     A群（思想文化）  B群（歴史文化_日本史学）  C群（歴史文化_東洋史学）  \
# 0    8543.204128  7759.717563  1567.711045     825.608822    1087.471587
# 1    8635.812719  6315.613846  1580.460670     825.873194    1223.102263
# 2    8736.591178  6499.671830  1579.942231     837.218689    1046.462732
# 3    8986.023000  6203.170189  1576.455255     852.947100    1069.555622
# 4    8436.906887  7104.341434  1628.806274     735.070503     907.915841
# ..           ...          ...          ...            ...            ...
# 996  7964.799884  6462.700468  1553.013752     849.843522    1317.537155
# 997  9137.912764  6995.260756  1592.648658     842.860421     876.094249
# 998  8328.693658  7280.049817  1553.365634     834.098459    1365.632659
# 999  8209.737657  6969.613760  1570.341061     844.465674     617.991167
# 合計値  8590.643263  6995.564945  1573.424119     829.357512    1091.525280
#
#      D群（歴史文化_西洋史学）  E群（歴史文化_考古学）  F群（歴史文化_美術史学）     G群（言語文化）     H群（心理学）  ...  \
# 0       887.929515    447.552293     342.441643  1626.387525  478.714263  ...
# 1       866.297326    214.867774     598.918803  2326.579068  476.979045  ...
# 2       833.580445    294.851043     506.272329  2127.739597  483.947335  ...
# 3       883.872885    352.182061     438.405573  2365.205070  483.198193  ...
# 4       896.120464    213.129810     292.591451  2751.347430  499.876093  ...
# ..             ...           ...            ...          ...         ...  ...
# 996     862.005062    357.923424     429.738244  2580.176037  486.479412  ...
# 997     893.626720      0.000000      75.244759  2332.702787  478.334478  ...
# 998     878.576485    154.123545     292.001807  2352.717329  486.037240  ...
# 999     882.736415    495.512643     353.548288  2742.012768  481.796204  ...
# 合計値     874.961700    271.805785     412.939568  2313.824515  484.607049  ...
#
#               数学        情報科学          物理学         天文学     地球惑星物理学     地球惑星環境学  \
# 0    1012.236509  776.825598  1594.366967  304.141679  765.250066  443.376730
# 1     986.982998  783.925499  1526.051034  303.601008  762.337675  462.366402
# 2     985.330741  789.869588  1543.107287  305.318673  772.181394  476.978193
# 3     984.768198  801.543738  1559.292173  324.233934  775.701495  500.094053
# 4     985.619324  775.115971  1606.382247  302.029991  774.975958  479.858729
# ..           ...         ...          ...         ...         ...         ...
# 996   972.903600  799.823924  1545.509209  316.893295  759.200142  470.411368
# 997   991.447887  777.903721  1590.708936  325.138361  763.680388  440.363441
# 998   980.550765  772.357309  1553.501001  317.685661  788.137798  466.376948
# 999   966.993004  772.918883  1542.745178  317.044896  754.818673  487.001490
# 合計値   974.100273  788.055959  1563.495124  313.852689  768.356950  474.721871
#
#               化学        生物化学      生物情報科学         生物学
# 0     990.828383  458.274896  396.878614  732.000381
# 1    1016.598928  468.316891  390.585768  746.141515
# 2    1016.532906  471.677150  399.215290  771.211128
# 3    1011.439392  473.185350  397.428367  750.550749
# 4    1009.202382  463.126745  380.747522  733.266838
# ..           ...         ...         ...         ...
# 996   986.930074  465.547151  398.237849  768.367940
# 997   990.847756  446.418588  386.083924  746.544814
# 998   999.956388  457.447379  379.816022  753.108893
# 999   987.608412  467.304874  393.601899  775.082760
# 合計値   988.371432  466.306949  394.186043  756.827496
#
# [1001 rows x 78 columns]

# %%
trial=1000
MQ_utility_dict=dict()
for f in fac:
    MQ_utility_dict[f]=[]
for n in range(trial):
    majority_acceptance_MQ=pd.read_csv(f"MultiThread/majority_acceptance_MQ{n}.csv", index_col=0, header=None)
    minority_acceptance_MQ=pd.read_csv(f"MultiThread/minority_acceptance_MQ{n}.csv", index_col=0, header=None)
    utilityDict=pd.read_csv(f"MultiThread/utilityDict{n}.csv",header=0, index_col=0).to_dict(orient="index")
    for f in fac:
        cnt=0
        accept_students=majority_acceptance_MQ.loc[f, :].dropna()
        utility=0
        for student in accept_students:
            utility+=utilityDict[student]["utility"]
            
        cnt+=len(accept_students)
            
        accept_students=minority_acceptance_MQ.loc[f, :].dropna()
        for student in accept_students:
            utility+=utilityDict[student]["utility"]
        cnt+=len(accept_students)
        
        if cnt!=0:
            MQ_utility_dict[f].append(utility/cnt)
        else:
            MQ_utility_dict[f].append(0)
# for f in fac:
#     MQ_utility_dict[f]={"効用の平均値":MQ_utility_dict[f]/trial}
MQ_utility_df=pd.DataFrame(MQ_utility_dict)
MQ_utility_df.to_csv("Result/旧制度での生徒の進学平均点.csv", encoding="utf-8-sig")
print(MQ_utility_df)
# Out:
#            法学部       経済学部   A群（思想文化）  B群（歴史文化_日本史学）  C群（歴史文化_東洋史学）  \
# 0    73.979732  73.189172  76.402651      76.827614      75.737215
# 1    74.126535  73.456387  76.418420      77.627238      76.736812
# 2    74.004432  74.018730  75.688850      76.082427      78.893220
    utilityDict=pd.read_csv(f"MultiThread/utilityDict{n}.csv",header=0, index_col=0).to_dict(orient="index")
    for f in fac:
        cnt=0
        accept_students=majority_acceptance_MQ.loc[f, :].dropna()
        utility=0
        for student in accept_students:
            utility+=utilityDict[student]["utility"]
            
        cnt+=len(accept_students)
        
        cnt_m=0
        utility_m=0    
        accept_students=minority_acceptance_MQ.loc[f, :].dropna()
        for student in accept_students:
            utility_m+=utilityDict[student]["utility"]
        cnt_m+=len(accept_students)
        
        if cnt!=0:
            MQ_utility_dict[f].append(utility/cnt)
        else:
            MQ_utility_dict[f].append(0)

        if cnt_m!=0:
            MQ_utility_dict_m[f].append(utility_m/cnt_m)
        else:
            MQ_utility_dict_m[f].append(0)
# for f in fac:
#     MQ_utility_dict[f]={"効用の平均値":MQ_utility_dict[f]/trial}
MQ_utility_df=pd.DataFrame(MQ_utility_dict)
MQ_utility_df.to_csv("Result/旧制度での生徒の進学平均点(全科類枠).csv", encoding="utf-8-sig")
print(MQ_utility_df)
MQ_utility_df_m=pd.DataFrame(MQ_utility_dict_m)
MQ_utility_df_m.to_csv("Result/旧制度での生徒の進学平均点(指定科類枠).csv", encoding="utf-8-sig")
print(MQ_utility_df_m)
# Out:
#            法学部       経済学部   A群（思想文化）  B群（歴史文化_日本史学）  C群（歴史文化_東洋史学）  \
# 0    73.358861  74.345368  78.280244      78.857060      76.648440
# 1    72.082887  73.588886  77.828686      80.499731      76.736812
# 2    72.095592  75.146277  78.187855      80.549168      78.893220
# 3    70.352839  72.925043  77.725324      80.420432      74.984588
# 4    72.738747  74.998803  79.345907      77.213938      80.608466
# ..         ...        ...        ...            ...            ...
# 995  73.146026  74.909189  78.989432      79.852911      77.990773
# 996  70.803041  74.579867  75.477805      83.936386      77.903364
# 997  72.998976  73.013804  78.716139      80.703965      75.717840
# 998  74.158832  74.963861  75.875547      80.321333      79.719534
# 999  69.761318  73.436817  77.487760      79.382156      80.038436
#
#      D群（歴史文化_西洋史学）  E群（歴史文化_考古学）  F群（歴史文化_美術史学）   G群（言語文化）    H群（心理学）  ...  \
# 0        85.964227     77.866248      64.342104  77.430740  78.999116  ...
# 1        80.313300     71.441896      75.568514  75.491544  78.510267  ...
# 2        79.044730     76.920252      72.694579  76.113071  78.879595  ...
# 3        83.719096     69.733259      74.282633  77.682923  80.555890  ...
# 4        84.730902     68.787342      72.822540  76.294188  82.565943  ...
# ..             ...           ...            ...        ...        ...  ...
# 995      85.267131     71.952154      71.255558  77.371581  85.223637  ...
# 996      80.897362     74.656057      70.438297  76.874277  80.262640  ...
# 997      84.238358     62.694237       0.000000  79.384731  78.341758  ...
# 998      82.388721     72.204728      68.769008  76.979219  79.730196  ...
# 999      82.020981     71.908355      68.514602  78.234006  78.919109  ...
#
#             数学       情報科学        物理学        天文学    地球惑星物理学    地球惑星環境学  化学  \
# 0    77.864347  77.682560  75.969550  76.035420  77.748609  72.065627   0
# 1    75.921769  78.392550  72.845781  75.900252  77.035750  74.906761   0
# 2    75.863209  78.986959  73.481299  76.639479  78.436689  77.559770   0
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ..   ...
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
#
# [1000 rows x 78 columns]

# %%
trial=1000
MQ_utility_dict=dict()
zero_count_MQ=dict()
for f in fac:
    MQ_utility_dict[f]=0
    zero_count_MQ[f]=0
for n in range(trial):
    majority_acceptance_MQ=pd.read_csv(f"MultiThread/majority_acceptance_MQ{n}.csv", index_col=0, header=None)
    minority_acceptance_MQ=pd.read_csv(f"MultiThread/minority_acceptance_MQ{n}.csv", index_col=0, header=None)
    utilityDict=pd.read_csv(f"MultiThread/utilityDict{n}.csv",header=0, index_col=0).to_dict(orient="index")
    for f in fac:
        cnt=0
        accept_students=majority_acceptance_MQ.loc[f, :].dropna()
        utility=0
        for student in accept_students:
            utility+=utilityDict[student]["utility"]
            
        cnt+=len(accept_students)
            
        accept_students=minority_acceptance_MQ.loc[f, :].dropna()
        for student in accept_students:
            utility+=utilityDict[student]["utility"]
        cnt+=len(accept_students)
        
        if cnt!=0:
            MQ_utility_dict[f]+=(utility/cnt)
        else:
            zero_count_MQ[f]+=1
for f in fac:
    MQ_utility_dict[f]={"効用の平均値":MQ_utility_dict[f]/(trial-zero_count_MQ[f])}
MQ_utility_df=pd.DataFrame(MQ_utility_dict).T
MQ_utility_df.to_csv("Result/旧制度での生徒の進学平均点(内定なし除く).csv", encoding="utf-8-sig")
print(MQ_utility_df)
# Out:
#                   効用の平均値
# 法学部            74.072597
# 経済学部           73.756507
# A群（思想文化）       75.846625
# B群（歴史文化_日本史学）  77.095882
# C群（歴史文化_東洋史学）  78.453392
# ...                  ...
# 地球惑星環境学        79.154045
# 化学             76.469520
# 生物化学           78.215585
# 生物情報科学         79.086085
# 生物学            76.291668
#
# [78 rows x 1 columns]

# %% [markdown]
# 旧制度での効用

# %%
trial=1000
MQ_utility_dict=dict()
for f in fac:
    MQ_utility_dict[f]=[]
for n in range(trial):
    majority_acceptance_MQ=pd.read_csv(f"MultiThread/majority_acceptance_MQ{n}.csv", index_col=0, header=None)
    minority_acceptance_MQ=pd.read_csv(f"MultiThread/minority_acceptance_MQ{n}.csv", index_col=0, header=None)
    utilityDict=pd.read_csv(f"MultiThread/utilityDict{n}.csv",header=0, index_col=0).to_dict(orient="index")
    for f in fac:
        accept_students=majority_acceptance_MQ.loc[f, :].dropna()
        utility=0
        for student in accept_students:
            utility+=utilityDict[student]["utility"]
            
        accept_students=minority_acceptance_MQ.loc[f, :].dropna()
        for student in accept_students:
            utility+=utilityDict[student]["utility"]
        MQ_utility_dict[f].append(utility)
# for f in fac:
#     MQ_utility_dict[f]={"効用の平均値":MQ_utility_dict[f]/trial}
MQ_utility_df=pd.DataFrame(MQ_utility_dict)
MQ_utility_df.loc["平均値"]=MQ_utility_df.mean()
MQ_utility_df.to_csv("Result/旧制度での学科の効用.csv", encoding="utf-8-sig")
print(MQ_utility_df)
# %% [markdown]
# MRの定員充足率(指定科類枠)

# %%
trial=1000
fill_dict=dict()
for f in fac:
    temp=dict()
    for key in set(minorityReserveDA[f].keys())-set(["0", "123456"]):
        temp[key]=0
    fill_dict[f]=temp
for n in range(trial):
    sim_fill=np.load(f"MultiThread/sim_fill{n}.npy", allow_pickle=True).item()
    for f in fac:
        mr_dict=sim_fill[f]
        for key in set(mr_dict.keys())-set(["0", "123456"]):
            mr_sim=len(mr_dict[key])
            mr_row=minorityReserveDA[f][key]
            if mr_row != 0:
                fill_dict[f][key]+=mr_sim/mr_row
            else:
                fill_dict[f][key]+=0
for f in fac:
    for key in fill_dict[f]:
        fill_dict[f][key]=fill_dict[f][key]/trial
print(fill_dict)
# Out:
# {'法学部': {'456': 1.0, '1': 0.9401818181818198, '23': 1.0}, '経済学部': {'456': 1.0, '2': 0.8952441860465222}, 'A群（思想文化）': {'3': 0.5915555555555564}, 'B群（歴史文化_日本史学）': {'3': 0.313142857142857}, 'C群（歴史文化_東洋史学）': {'3': 0.009769230769230756}, 'D群（歴史文化_西洋史学）': {'3': 0.2354999999999996}, 'E群（歴史文化_考古学）': {'3': 0.01838461538461533}, 'F群（歴史文化_美術史学）': {'3': 0.19310714285714253}, 'G群（言語文化）': {'3': 0.37358333333333277}, 'H群（心理学）': {'3': 1.0}, 'I群（社会心理学）': {'3': 0.9259999999999993}, 'J群（社会学）': {'3': 1.0}, '基礎教育学': {'3': 0.65075}, '比較教育社会学': {'3': 1.0}, '教育実践・政策学': {'3': 0.9955}, '教育心理学': {'456': 0.992, '3': 1.0}, '身体教育学': {}, '薬学部': {'456': 0.8608275862068916}, '医学': {'5': 1.0, '6': 0.99534375}, '健康総合科学': {'456': 0.5059090909090914}, '超域文化科学': {'3': 1.0, '12': 0.9915}, '地域文化研究': {'3': 0.7511666666666674, '12': 0.9556666666666653}, '総合社会科学': {'3': 1.0, '12': 0.995}, '数理自然科学': {'456': 1.0}, '物質基礎科学': {'456': 1.0}, '統合生命科学': {'456': 0.998625}, '認知行動科学': {'123': 1.0, '456': 1.0}, 'Ａ 群': {'123': 0.99575, '456': 1.0}, 'Ｂ 群': {'123': 0.998, '456': 1.0}, '教養学科国際日本研究コース': {}, '学際科学科国際環境学コース': {}, '生命化学・工学': {'456': 0.6519375}, '応用生物学': {'456': 0.46530769230769187}, '森林生物科学': {'456': 0.6995}, '水圏生物科学': {'456': 0.9993333333333334}, '動物生命システム科学': {'456': 1.0}, '生物素材化学': {'456': 0.9978333333333333}, '緑地環境学': {'456': 1.0}, '森林環境資源科学': {'456': 1.0}, '木質構造科学': {'456': 1.0}, '生物・環境工学': {'123': 0.154, '456': 0.8411999999999992}, '農業・資源経済学': {'123': 0.8581999999999983, '456': 1.0}, 'フィールド科学': {'456': 1.0}, '国際開発農学': {'456': 1.0}, '獣医学課程獣医学': {'456': 0.836}, '社会基盤学Ａ（設計・技術戦略）': {'4': 0.9931428571428573, '56': 0.0}, '社会基盤学Ｂ（政策・計画）社会基盤学Ｃ': {'4': 0.996, '56': 0.0}, '社会基盤学Ｃ（国際プロジェクト）': {'4': 0.9983333333333333, '56': 0.0}, '建築学': {'4': 1.0, '56': 0.0}, '都市環境工学（環境共生・国際公共衛生・水・環境ﾊﾞｲｵ）': {'4': 1.0, '56': 0.0}, '都市計画（都市と地域の分析・計画・ﾃﾞｻﾞｲﾝ）': {'4': 1.0, '56': 0.0}, '機械工学A（ﾃﾞｻﾞｲﾝ・ｴﾈﾙｷﾞｰ・ﾀﾞｲﾅﾐｸｽ）': {'4': 1.0, '56': 0.0}, '機械工学B': {'4': 1.0, '56': 0.0}, '航空宇宙学': {'4': 0.9988888888888889, '56': 0.0}, '精密工学': {'4': 1.0, '56': 0.0}, '電子情報工学': {'4': 1.0, '56': 0.0}, '電気電子工学': {'4': 1.0, '56': 0.0}, '応用物理・物理工学': {'4': 1.0, '56': 0.0}, '計数工学・数理/ｼｽﾃﾑ情報': {'4': 1.0, '56': 0.0}, 'マテリアル工学A': {'4': 0.8125714285714273, '56': 0.766}, 'マテリアル工学B': {'4': 0.9236470588235319, '56': 0.0}, 'マテリアル工学C (ﾅﾉ・機能ﾏﾃﾘｱﾙ）': {'4': 1.0, '56': 0.0}, '応用化学': {'4': 0.24618181818181806, '56': 1.0}, '化学システム工学': {'4': 0.567625, '56': 1.0}, '化学生命工学': {'4': 0.53, '56': 1.0}, 'システム創成A': {'4': 0.7766666666666666, '56': 0.713}, 'システム創成B': {'4': 1.0, '56': 0.0}, 'システム創成C': {'4': 1.0, '56': 1.0}, '数学': {'456': 0.0}, '情報科学': {'456': 0.0}, '物理学': {'456': 0.0}, '天文学': {'456': 0.0}, '地球惑星物理学': {'456': 0.0}, '地球惑星環境学': {'456': 1.0}, '化学': {'456': 1.0}, '生物化学': {'456': 1.0}, '生物情報科学': {'456': 1.0}, '生物学': {'456': 0.0}}

# %%
trial=1000
fill_dict_zen=dict()
for f in fac:
    fill_dict_zen[f]=0
for n in range(trial):
    majority_acceptance_MQ=pd.read_csv(f"MultiThread/majority_acceptance_MQ{n}.csv", index_col=0, header=None)
    for f in fac:
        students=majority_acceptance_MQ.loc[f].dropna()
        if minorityReserveDA[f]["123456"]!=0:
            fill_dict_zen[f]+=len(students)/minorityReserveDA[f]["123456"]
        else:
            fill_dict_zen[f]+=0
for f in fac:
    fill_dict_zen[f]=fill_dict_zen[f]/trial
print(fill_dict_zen)
# Out:
# {'法学部': 0.9713428571428561, '経済学部': 1.0, 'A群（思想文化）': 1.0, 'B群（歴史文化_日本史学）': 1.0, 'C群（歴史文化_東洋史学）': 1.0, 'D群（歴史文化_西洋史学）': 1.0, 'E群（歴史文化_考古学）': 0.8946666666666657, 'F群（歴史文化_美術史学）': 0.5065, 'G群（言語文化）': 0.9996666666666666, 'H群（心理学）': 1.0, 'I群（社会心理学）': 1.0, 'J群（社会学）': 0.9998571428571429, '基礎教育学': 0.919333333333332, '比較教育社会学': 1.0, '教育実践・政策学': 0.98125, '教育心理学': 1.0, '身体教育学': 0.5441999999999995, '薬学部': 0.1615, '医学': 1.0, '健康総合科学': 0.13850000000000007, '超域文化科学': 1.0, '地域文化研究': 1.0, '総合社会科学': 1.0, '数理自然科学': 0.0, '物質基礎科学': 0.0, '統合生命科学': 0.988, '認知行動科学': 0.0, 'Ａ 群': 0.0, 'Ｂ 群': 0.0, '教養学科国際日本研究コース': 0.35925, '学際科学科国際環境学コース': 0.4115, '生命化学・工学': 0.0, '応用生物学': 0.0, '森林生物科学': 0.147, '水圏生物科学': 0.0, '動物生命システム科学': 0.0, '生物素材化学': 0.0, '緑地環境学': 0.0, '森林環境資源科学': 0.8281999999999983, '木質構造科学': 0.0, '生物・環境工学': 0.07708333333333335, '農業・資源経済学': 0.0, 'フィールド科学': 1.0, '国際開発農学': 1.0, '獣医学課程獣医学': 0.0, '社会基盤学Ａ（設計・技術戦略）': 0.0, '社会基盤学Ｂ（政策・計画）社会基盤学Ｃ': 0.0, '社会基盤学Ｃ（国際プロジェクト）': 0.0, '建築学': 1.0, '都市環境工学（環境共生・国際公共衛生・水・環境ﾊﾞｲｵ）': 1.0, '都市計画（都市と地域の分析・計画・ﾃﾞｻﾞｲﾝ）': 0.0, '機械工学A（ﾃﾞｻﾞｲﾝ・ｴﾈﾙｷﾞｰ・ﾀﾞｲﾅﾐｸｽ）': 0.0, '機械工学B': 0.0, '航空宇宙学': 0.0, '精密工学': 1.0, '電子情報工学': 1.0, '電気電子工学': 0.0, '応用物理・物理工学': 1.0, '計数工学・数理/ｼｽﾃﾑ情報': 1.0, 'マテリアル工学A': 0.457, 'マテリアル工学B': 0.0, 'マテリアル工学C (ﾅﾉ・機能ﾏﾃﾘｱﾙ）': 0.0, '応用化学': 0.0, '化学システム工学': 0.0, '化学生命工学': 1.0, 'システム創成A': 0.2973333333333338, 'システム創成B': 0.0, 'システム創成C': 0.0, '数学': 0.9989230769230769, '情報科学': 1.0, '物理学': 0.9998571428571429, '天文学': 1.0, '地球惑星物理学': 1.0, '地球惑星環境学': 1.0, '化学': 0.0, '生物化学': 0.0, '生物情報科学': 0.0, '生物学': 0.9996999999999999}

# %% [markdown]
# 受入数(MQ)

# %%
trial=1000
amount_of_acceptance_MQ=dict()
count_0_MQ=dict()
for f in fac:
    amount_of_acceptance_MQ[f]=0
    count_0_MQ[f]=0
for n in range(trial):
    minority_acceptance_MQ=pd.read_csv(f"MultiThread/minority_acceptance_MQ{n}.csv", index_col=0, header=None)
    majority_acceptance_MQ=pd.read_csv(f"MultiThread/majority_acceptance_MQ{n}.csv", index_col=0, header=None)
    for f in fac:
        amount_of_acceptance_MQ[f]+=len(minority_acceptance_MQ.loc[f].dropna(0))
        amount_of_acceptance_MQ[f]+=len(majority_acceptance_MQ.loc[f].dropna(0))
        if len(majority_acceptance_MQ.loc[f].dropna(0))+len(minority_acceptance_MQ.loc[f].dropna(0)) == 0:
            count_0_MQ[f]+=1
        
for f in fac:
    amount_of_acceptance_MQ[f]=amount_of_acceptance_MQ[f]/trial
    count_0_MQ[f]={"受入数0の回数":count_0_MQ[f]}
for f in fac:
    amount_of_acceptance_MQ[f]={"受入数":amount_of_acceptance_MQ[f]}
df_aa_MQ=pd.DataFrame(amount_of_acceptance_MQ).T
df_count_0_MQ=pd.DataFrame(count_0_MQ).T
print(df_aa_MQ)
print(df_count_0_MQ)
df_aa_MQ.to_csv("Result/受入数MQ.csv", encoding="utf-8-sig")
df_count_0_MQ.to_csv("Result/受け入れ数0の回数_MQ.csv", encoding="utf-8-sig")
# Out:
#                    受入数
# 法学部            120.733
# 経済学部            97.991
# A群（思想文化）        17.324
# B群（歴史文化_日本史学）    6.192
# C群（歴史文化_東洋史学）    6.127
# ...                ...
# 地球惑星環境学          6.000
# 化学              13.000
# 生物化学             6.000
# 生物情報科学           5.000
# 生物学              9.997
#
# [78 rows x 1 columns]
#                受入数0の回数
# 法学部                  0
# 経済学部                 0
# A群（思想文化）             0
# B群（歴史文化_日本史学）        0
# C群（歴史文化_東洋史学）        0
# ...                ...
# 地球惑星環境学              0
# 化学                   0
# 生物化学                 0
# 生物情報科学               0
# 生物学                  0
#
# [78 rows x 1 columns]

# %% [markdown]
# 枠別受入数(MQ)

# %%
trial=1000
amount_of_minority_acceptance_MQ=dict()
amount_of_majority_acceptance_MQ=dict()
for f in fac:
    amount_of_minority_acceptance_MQ[f]=0
    amount_of_majority_acceptance_MQ[f]=0
for n in range(trial):
    minority_acceptance_MQ=pd.read_csv(f"MultiThread/minority_acceptance_MQ{n}.csv", index_col=0, header=None)
    majority_acceptance_MQ=pd.read_csv(f"MultiThread/majority_acceptance_MQ{n}.csv", index_col=0, header=None)
    for f in fac:
        amount_of_minority_acceptance_MQ[f]+=len(minority_acceptance_MQ.loc[f].dropna(0))
        amount_of_majority_acceptance_MQ[f]+=len(majority_acceptance_MQ.loc[f].dropna(0))
        
for f in fac:
    amount_of_minority_acceptance_MQ[f]=amount_of_minority_acceptance_MQ[f]/trial
for f in fac:
    amount_of_minority_acceptance_MQ[f]={"受入数":amount_of_minority_acceptance_MQ[f]}
for f in fac:
    amount_of_majority_acceptance_MQ[f]=amount_of_majority_acceptance_MQ[f]/trial
for f in fac:
    amount_of_majority_acceptance_MQ[f]={"受入数":amount_of_majority_acceptance_MQ[f]}
df_ma_MQ=pd.DataFrame(amount_of_minority_acceptance_MQ).T
print(df_ma_MQ)
df_Ma_MQ=pd.DataFrame(amount_of_majority_acceptance_MQ).T
print(df_Ma_MQ)
df_ma_MQ.to_csv("Result/受入数MQ(指定科類枠).csv", encoding="utf-8-sig")
df_Ma_MQ.to_csv("Result/受入数MQ(全科類枠).csv", encoding="utf-8-sig")
# Out:
#                   受入数
# 法学部            86.736
# 経済学部           79.991
# A群（思想文化）        5.324
# B群（歴史文化_日本史学）   2.192
# C群（歴史文化_東洋史学）   0.127
# ...               ...
# 地球惑星環境学         4.000
# 化学             13.000
# 生物化学            6.000
# 生物情報科学          5.000
# 生物学             0.000
#
# [78 rows x 1 columns]
#                   受入数
# 法学部            33.997
# 経済学部           18.000
# A群（思想文化）       12.000
# B群（歴史文化_日本史学）   4.000
# C群（歴史文化_東洋史学）   6.000
# ...               ...
# 地球惑星環境学         2.000
# 化学              0.000
# 生物化学            0.000
# 生物情報科学          0.000
# 生物学             9.997
#
# [78 rows x 1 columns]

# %%
trial=1000
amount_of_acceptance_MQ=dict()
count_0_MQ=dict()
for f in fac:
    amount_of_acceptance_MQ[f]=0
    count_0_MQ[f]=0
for n in range(trial):
    minority_acceptance_MQ=pd.read_csv(f"MultiThread/minority_acceptance_MQ{n}.csv", index_col=0, header=None)
    majority_acceptance_MQ=pd.read_csv(f"MultiThread/majority_acceptance_MQ{n}.csv", index_col=0, header=None)
    for f in fac:
        amount_of_acceptance_MQ[f]+=len(minority_acceptance_MQ.loc[f].dropna())
        amount_of_acceptance_MQ[f]+=len(majority_acceptance_MQ.loc[f].dropna())
        if len(majority_acceptance_MQ.loc[f].dropna()) == 0:
            count_0_MQ[f]+=1
        
for f in fac:
    amount_of_acceptance_MQ[f]=amount_of_acceptance_MQ[f]/trial
    count_0_MQ[f]={"受入数0の回数":count_0_MQ[f]}
for f in fac:
    amount_of_acceptance_MQ[f]={"受入数":amount_of_acceptance_MQ[f]}
print(count_0_MQ["化学システム工学"])
# Out:
# {'受入数0の回数': 1000}

# %% [markdown]
# 受入数(MR)

# %%
trial=1000
amount_of_acceptance_MR=dict()
count_0_MR=dict()
for f in fac:
    amount_of_acceptance_MR[f]=0
    count_0_MR[f]=0
for n in range(trial):
    minority_acceptance_MR=pd.read_csv(f"MultiThread/minority_acceptance_MR{n}.csv", index_col=0, header=None)
    majority_acceptance_MR=pd.read_csv(f"MultiThread/majority_acceptance_MR{n}.csv", index_col=0, header=None)
    for f in fac:
        amount_of_acceptance_MR[f]+=len(minority_acceptance_MR.loc[f].dropna())
        amount_of_acceptance_MR[f]+=len(majority_acceptance_MR.loc[f].dropna())
        if len(minority_acceptance_MR.loc[f].dropna(0))+len(majority_acceptance_MR.loc[f].dropna(0)) == 0:
            count_0_MR[f]+=1
            
for f in fac:
    amount_of_acceptance_MR[f]=amount_of_acceptance_MR[f]/trial
    
for f in fac:
    amount_of_acceptance_MR[f]={"受入数":amount_of_acceptance_MR[f]}
    count_0_MR[f]={"受入数0の回数":count_0_MR[f]}
df_aa_MR=pd.DataFrame(amount_of_acceptance_MR).T
df_count_0_MR=pd.DataFrame(count_0_MR).T
    
print(df_aa_MR)
print(df_count_0_MR)
df_aa_MR.to_csv("Result/受入数MR.csv", encoding="utf-8-sig")
df_count_0_MR.to_csv("Result/受入れ数0の回数_MR.csv", encoding="utf-8-sig")
# Out:
#                受入数0の回数
# 法学部            116.076
# 経済学部            95.871
# A群（思想文化）        20.966
# B群（歴史文化_日本史学）   10.935
# C群（歴史文化_東洋史学）   14.726
# ...                ...
# 地球惑星環境学          6.000
# 化学              12.995
# 生物化学             6.000
# 生物情報科学           5.000
# 生物学              9.982
#
# [78 rows x 1 columns]
#                受入数
# 法学部              0
# 経済学部             0
# A群（思想文化）         0
# B群（歴史文化_日本史学）    0
# C群（歴史文化_東洋史学）    0
# ...            ...
# 地球惑星環境学          0
# 化学               0
# 生物化学             0
# 生物情報科学           0
# 生物学              0
#
# [78 rows x 1 columns]

# %%
trial=1000
amount_of_acceptance_MR=dict()
count_0_MR=dict()
for f in fac:
    amount_of_acceptance_MR[f]=0
    count_0_MR[f]=0
for n in range(trial):
    minority_acceptance_MR=pd.read_csv(f"MultiThread/minority_acceptance_MR{n}.csv", index_col=0, header=None)
    majority_acceptance_MR=pd.read_csv(f"MultiThread/majority_acceptance_MR{n}.csv", index_col=0, header=None)
    for f in fac:
        amount_of_acceptance_MR[f]+=len(minority_acceptance_MR.loc[f].dropna())
        amount_of_acceptance_MR[f]+=len(majority_acceptance_MR.loc[f].dropna())
        if len(majority_acceptance_MR.loc[f].dropna()) == 0:
            count_0_MR[f]+=1
            
for f in fac:
    amount_of_acceptance_MR[f]=amount_of_acceptance_MR[f]/trial
    
for f in fac:
    amount_of_acceptance_MR[f]={"受入数0の回数":amount_of_acceptance_MR[f]}
    count_0_MR[f]={"受入数":count_0_MR[f]}
print(count_0_MR["化学システム工学"])
# Out:
# {'受入数': 2}

# %%
trial=1000
amount_of_minority_acceptance_MR=dict()
amount_of_majority_acceptance_MR=dict()
for f in fac:
    amount_of_minority_acceptance_MR[f]=0
    amount_of_majority_acceptance_MR[f]=0
for n in range(trial):
    minority_acceptance_MR=pd.read_csv(f"MultiThread/minority_acceptance_MR{n}.csv", index_col=0, header=None)
    majority_acceptance_MR=pd.read_csv(f"MultiThread/majority_acceptance_MR{n}.csv", index_col=0, header=None)
    for f in fac:
        amount_of_minority_acceptance_MR[f]+=len(minority_acceptance_MR.loc[f].dropna(0))
        amount_of_majority_acceptance_MR[f]+=len(majority_acceptance_MR.loc[f].dropna(0))
        
for f in fac:
    amount_of_minority_acceptance_MR[f]=amount_of_minority_acceptance_MR[f]/trial
for f in fac:
    amount_of_minority_acceptance_MR[f]={"受入数":amount_of_minority_acceptance_MR[f]}
for f in fac:
    amount_of_majority_acceptance_MR[f]=amount_of_majority_acceptance_MR[f]/trial
for f in fac:
    amount_of_majority_acceptance_MR[f]={"受入数":amount_of_majority_acceptance_MR[f]}
df_ma_MR=pd.DataFrame(amount_of_minority_acceptance_MR).T
print(df_ma_MR)
df_Ma_MR=pd.DataFrame(amount_of_majority_acceptance_MR).T
print(df_Ma_MR)
df_ma_MR.to_csv("Result/受入数MR(指定科類枠).csv", encoding="utf-8-sig")
df_Ma_MR.to_csv("Result/受入数MR(全科類枠).csv", encoding="utf-8-sig")
# Out:
#                   受入数
# 法学部            83.152
# 経済学部           62.888
# A群（思想文化）        4.884
# B群（歴史文化_日本史学）   1.996
# C群（歴史文化_東洋史学）   0.084
# ...               ...
# 地球惑星環境学         4.000
# 化学             12.995
# 生物化学            6.000
# 生物情報科学          5.000
# 生物学             0.000
#
# [78 rows x 1 columns]
#                   受入数
# 法学部            32.924
# 経済学部           32.983
# A群（思想文化）       16.082
# B群（歴史文化_日本史学）   8.939
# C群（歴史文化_東洋史学）  14.642
# ...               ...
# 地球惑星環境学         2.000
# 化学              0.000
# 生物化学            0.000
# 生物情報科学          0.000
# 生物学             9.982
#
# [78 rows x 1 columns]
